# %% [markdown]
# ## Import dependencies

# %%
import random
import copy
import logging
import statistics
import numpy as np

# Get the root logger and set its level to DEBUG
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ## Set up classes

# %%
class Squad:
    def __init__(self, name, *unit_pairs):
        self.name = name
        self.unit_pairs = unit_pairs
        self.units = []
        self.spawn_squad()

    def spawn_squad(self):
        self.units = []
        for unit, count in self.unit_pairs:
            self.units.extend([copy.deepcopy(unit) for _ in range(count)])
    
    def reset_squad_health(self):
        for unit in self.units:
            unit.health = unit.max_health
    
    def is_alive(self):
        return any(unit.health > 0 for unit in self.units)

    def get_alive_unit(self):
        for unit in self.units:
            if unit.is_alive():
                return unit
        return None
    
    def total_health(self):
        return sum(unit.health for unit in self.units)

class Weapon:
    def __init__(self, name, attacks, ballistic_skill, strength, armor_piercing, damage):
        self.name = name
        self.attacks = attacks
        self.ballistic_skill = ballistic_skill
        self.strength = strength
        self.armor_piercing = armor_piercing
        self.damage = damage

    def get_attacks(self):
        if callable(self.attacks):
            dice_roll,added_number=self.attacks()
            number_of_attacks=dice_roll+added_number
            logging.debug(f"The method is: {self.get_attacks.__name__}. The amount of damage was: {number_of_attacks}. The dice roll was {dice_roll} and the added number was {added_number}")
            return number_of_attacks
        else:
            return self.attacks
        
    def get_damage(self):
        if callable(self.damage):
            dice_roll,added_number=self.damage()
            number_of_damage=dice_roll+added_number
            logging.debug(f"The method is: {self.get_damage.__name__}. The amount of damage was: {number_of_damage}. The dice roll was {dice_roll} and the added number was {added_number}")
            return number_of_damage
        else:
            return self.damage

class Unit:
    def __init__(self, name, weapons, toughness, armor, max_health, feel_no_pain=None, invulnerable_save=None,):
        self.name = name
        self.weapons = weapons
        self.toughness = toughness
        self.armor = armor
        self.invulnerable_save = invulnerable_save
        self.max_health = max_health
        self.health = max_health
        self.feel_no_pain = feel_no_pain

    def roll_dice(self):
        return random.randint(1, 6)

    def does_it_hit(self, weapon):
        dice_roll = self.roll_dice()
        outcome = dice_roll >= weapon.ballistic_skill
        logging.debug(f"The method is: {self.does_it_hit.__name__}. Weapon: {weapon.name}, Dice Roll: {str(dice_roll)}, Ballistic Skill: {weapon.ballistic_skill}, Outcome: {outcome}")
        return dice_roll >= weapon.ballistic_skill

    def does_it_wound(self, opponent_toughness, weapon):
        roll = self.roll_dice()
        outcome = False
        if weapon.strength == opponent_toughness and roll >= 4:
            outcome = True
        elif weapon.strength > opponent_toughness and roll >= 3:
            outcome = True
        elif weapon.strength >= 2 * opponent_toughness and roll >= 2:
            outcome = True
        elif weapon.strength < opponent_toughness and roll >= 5:
            outcome = True
        elif weapon.strength <= 0.5 * opponent_toughness and roll == 6:
            outcome = True

        logging.debug(f"The method is: {self.does_it_wound.__name__}. Weapon: {weapon.name}, Dice Roll: {str(roll)}, Opponent Toughness: {opponent_toughness}, Outcome: {outcome}")
        return outcome

    def does_it_pass_through_armor(self, weapon):
        if self.invulnerable_save:
            modified_armor = min(self.invulnerable_save, self.armor - weapon.armor_piercing)
        else:
            modified_armor=self.armor - weapon.armor_piercing
        dice_roll = self.roll_dice()
        outcome = dice_roll < modified_armor
        logging.debug(f"The method is: {self.does_it_pass_through_armor.__name__}, Weapon: {weapon.name}, Dice Roll: {str(dice_roll)}, Modified Armor: {modified_armor}, Outcome: {outcome}")
        return outcome

    def feel_no_pain_save(self,damage):
        if self.feel_no_pain:
            remaining_damage=0
            for _ in range(damage):
                dice_roll = self.roll_dice()
                if dice_roll < self.feel_no_pain:
                    remaining_damage += 1
            logging.debug(f"The method is: {self.feel_no_pain_save.__name__}, Unit: {self.name},Incoming damage: {damage}, Remaining damage: {remaining_damage}")
        else:
            remaining_damage=damage
            logging.debug(f"The method is: {self.feel_no_pain_save.__name__}, No feel no pain.,Incoming damage: {damage}, Remaining damage: {remaining_damage}")
        return remaining_damage
    
    def is_alive(self):
        return self.health > 0

# %%
# unit_pairs=[(assault_intercessor_ranged, 2)]

# testunits = []
# for unit, count in unit_pairs:
#     # testunits.extend([copy.deepcopy(unit) for _ in range(count)])
#     testunits.extend([unit for _ in range(count)])
#     testunits[0].health = 99
# testunits

# %% [markdown]
# ## Set up Weapons, Units and Squads

# %%
# Variable number of attacks
def roll_dice_plus_variable(dice_number,added_variable):
    return random.randint(1, dice_number),added_variable

# Create weapons
bolter = Weapon(name='bolter', attacks=2, ballistic_skill=3, strength=4, armor_piercing=0, damage=2)
genestealer_claws = Weapon(name='genestealer_claws',attacks=4, ballistic_skill=2, strength=4, armor_piercing=-2, damage=1)
heavy_bolt_pistol = Weapon(name='heavy_bolt_pistol', attacks=1, ballistic_skill=3, strength=4, armor_piercing=-1, damage=1)
astartes_chainsword = Weapon(name='astartes_chainsword', attacks=4, ballistic_skill=3, strength=4, armor_piercing=-1, damage=1)
old_one_eye_strike = Weapon(name='old_one_eye_strike', attacks=6, ballistic_skill=3, strength=14, armor_piercing=-3, damage=lambda: roll_dice_plus_variable(6,1))
old_one_eye_sweep = Weapon(name='old_one_eye_sweep', attacks=12, ballistic_skill=3, strength=6, armor_piercing=-1, damage=1)
macro_plasma_incinerator = Weapon(name='macro_plasma_incinerator', attacks=lambda: roll_dice_plus_variable(6,1), ballistic_skill=3, strength=8, armor_piercing=-3, damage=2)
macro_plasma_incinerator_supercharged = Weapon(name='macro_plasma_incinerator', attacks=lambda: roll_dice_plus_variable(6,1), ballistic_skill=3, strength=9, armor_piercing=-4, damage=3)
storm_bolter = Weapon(name='storm_bolter', attacks=4, ballistic_skill=3, strength=4, armor_piercing=0, damage=1)
onslaught_gatling_gun = Weapon(name='onslaught_gatling_gun', attacks=8, ballistic_skill=3, strength=5, armor_piercing=0, damage=1)




# Create units
assault_intercessor_ranged = Unit(name='assault_intercessor_ranged', weapons=[heavy_bolt_pistol], toughness=4, armor=3,  max_health=2)
assault_intercessor_melee = Unit(name='assault_intercessor_melee', weapons=[heavy_bolt_pistol,astartes_chainsword], toughness=4, armor=3,  max_health=2)
genestealer = Unit(name='Genestealer', weapons=[genestealer_claws], toughness=4, armor=5,  max_health=2, invulnerable_save=5)
old_one_eye=Unit(name='old_one_eye', weapons=[old_one_eye_strike,old_one_eye_sweep], toughness=9, armor=2,  max_health=9, feel_no_pain=5)
redemptor_dreadnought_ranged=Unit(name='redemptor_dreadnought_ranged', weapons=[macro_plasma_incinerator,storm_bolter,onslaught_gatling_gun], toughness=10, armor=2,  max_health=12)
redemptor_dreadnought_ranged_supercharged=Unit(name='redemptor_dreadnought_ranged', weapons=[macro_plasma_incinerator_supercharged,storm_bolter,onslaught_gatling_gun], toughness=10, armor=2,  max_health=12)


assault_intercessor_ranged_squad = Squad('Assault Intercessor Ranged Squad', (assault_intercessor_ranged, 5))
assault_intercessor_melee_squad = Squad('Assault Intercessor Melee Squad', (assault_intercessor_melee, 5))
genestealer_squad = Squad('Genestealer Squad', (genestealer, 10))
old_one_eye_squad = Squad('Old One Eye Squad', (old_one_eye, 1))  # Assuming you want only one Old One Eye in the squad
redemptor_dreadnought_ranged_squad = Squad('Redemptor Dreadnought Ranged Squad', (redemptor_dreadnought_ranged, 1))
redemptor_dreadnought_ranged_supercharged_squad = Squad('Redemptor Dreadnought Ranged Supercharged Squad', (redemptor_dreadnought_ranged_supercharged, 1))

# %% [markdown]
# ## Set up simulation

# %%
class Simulation:
    def __init__(self, attacker_squad, defender_squad, trials=5):
        attacker_squad.spawn_squad()
        defender_squad.spawn_squad()
        self.attacker_squad = attacker_squad
        self.defender_squad = defender_squad
        self.trials = trials
        self.initial_defender_squad_health=defender_squad.total_health()
        self.initial_number_of_defender_units=len(defender_squad.units)


    def run(self):
        damage_results=[]
        health_reduced_results=[]
        death_results=[]
        for _ in range(self.trials):
            logging.debug("\n\n\nStarting a new trial")
            total_damage = 0
            total_health_reduced = 0
            total_deaths = 0
            self.attacker_squad.reset_squad_health()
            self.defender_squad.reset_squad_health()
            for attacker in self.attacker_squad.units:
                for weapon in attacker.weapons:
                    for _ in range(weapon.get_attacks()):
                        if attacker.does_it_hit(weapon):
                            defender = self.defender_squad.get_alive_unit()
                            if defender is None:
                                logging.debug("All units in the squad are dead")
                                break
                            if attacker.does_it_wound(defender.toughness, weapon):
                                if defender.does_it_pass_through_armor(weapon):
                                    damage = weapon.get_damage()
                                    remaining_damage=defender.feel_no_pain_save(damage)
                                    logging.debug(f"Unit: {defender.name}, Health: {defender.health}, Damage: {remaining_damage}")
                                    total_damage += remaining_damage
                                    for _ in range(remaining_damage):
                                        defender.health -= 1
                                        total_health_reduced += 1
                                        logging.debug(f"Reduced one health. total health reduced is: {total_health_reduced}")

                                        if defender.health <= 0:
                                            total_deaths += 1
                                            remaining_units = sum(1 for unit in self.defender_squad.units if unit.health > 0)
                                            initial_number_of_units = sum(1 for unit in self.defender_squad.units)

                                            logging.debug(f"Unit: {defender.name} has died : (  {remaining_units} remaining out of {initial_number_of_units}.")
                                            break
            damage_results.append(total_damage)
            health_reduced_results.append(total_health_reduced)
            death_results.append(total_deaths)
        return {"damage":damage_results,"health_reduced":health_reduced_results,"deaths":death_results,"initial_defender_squad_health":self.initial_defender_squad_health}

# %% [markdown]
# ## Performance profiling

# %%
import cProfile
import pstats

logger.setLevel(logging.INFO)
number_of_trials=10000
def run_many_simulations():
    # for _ in range(number_of_trials):
    simulation = Simulation(redemptor_dreadnought_ranged_squad, old_one_eye_squad, trials=number_of_trials)
    result = simulation.run()

profiler = cProfile.Profile()
profiler.enable()
run_many_simulations()
profiler.disable()
stats = pstats.Stats(profiler).sort_stats('cumtime')
stats.print_stats()

# Get the total time
total_time = sum([x.totaltime for x in profiler.getstats()])
logger.info(f'Average time per simulation: {round(total_time/number_of_trials,4)}')
# Out:
# INFO:root:Average time per simulation: 0.0007
#          5324546 function calls (5324425 primitive calls) in 0.979 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.979    0.489 /Users/lucastamatescumicrosoft/Code/warhammer-40K-simulator/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3517(run_code)
#         2    0.000    0.000    0.979    0.489 {built-in method builtins.exec}
#         1    0.000    0.000    0.979    0.979 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/274802400.py:6(run_many_simulations)
#         1    0.089    0.089    0.979    0.979 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/1181690119.py:12(run)
#    165119    0.105    0.000    0.395    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:70(does_it_hit)
#    329943    0.053    0.000    0.384    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:67(roll_dice)
#    339943    0.056    0.000    0.341    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/random.py:358(randint)
#    339943    0.138    0.000    0.285    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/random.py:284(randrange)
#    110189    0.084    0.000    0.279    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:76(does_it_wound)
#    366228    0.119    0.000    0.218    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:2150(debug)
#    339943    0.087    0.000    0.116    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/random.py:235(_randbelow_with_getrandbits)
#     36812    0.025    0.000    0.090    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:93(does_it_pass_through_armor)
#    366228    0.053    0.000    0.085    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:1467(debug)
#     11109    0.009    0.000    0.037    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:103(feel_no_pain_save)
#     30000    0.011    0.000    0.033    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:38(get_attacks)
#    366228    0.032    0.000    0.032    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:1734(isEnabledFor)
#   1019829    0.031    0.000    0.031    0.000 {built-in method _operator.index}
#    110189    0.022    0.000    0.030    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:20(get_alive_unit)
#    453423    0.017    0.000    0.017    0.000 {method 'getrandbits' of '_random.Random' objects}
#     10000    0.002    0.000    0.015    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/2580247398.py:12(<lambda>)
#    366230    0.014    0.000    0.014    0.000 {built-in method builtins.len}
#     10000    0.002    0.000    0.013    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/2580247398.py:2(roll_dice_plus_variable)
#    339943    0.012    0.000    0.012    0.000 {method 'bit_length' of 'int' objects}
#    110189    0.008    0.000    0.008    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:116(is_alive)
#     20000    0.003    0.000    0.003    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:13(reset_squad_health)
#     11109    0.002    0.000    0.002    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:47(get_damage)
#     41109    0.002    0.000    0.002    0.000 {built-in method builtins.callable}
#     30021    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/1181690119.py:2(__init__)
#         2    0.000    0.000    0.000    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:8(spawn_squad)
#         2    0.000    0.000    0.000    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:11(<listcomp>)
#     113/2    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copy.py:128(deepcopy)
#       7/2    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copy.py:259(_reconstruct)
#       7/2    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copy.py:227(_deepcopy_dict)
#         2    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copy.py:201(_deepcopy_list)
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:1953(basicConfig)
#         2    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/codeop.py:117(__call__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:1076(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:882(__init__)
#       233    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:912(createLock)
#        14    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copy.py:264(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:576(__init__)
#        16    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copy.py:243(_keep_alive)
#         2    0.000    0.000    0.000    0.000 /Users/lucastamatescumicrosoft/Code/warhammer-40K-simulator/.venv/lib/python3.11/site-packages/traitlets/traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:287(helper)
#       147    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:256(_register_at_fork_reinit_lock)
#         2    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:132(__enter__)
#         2    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:104(__init__)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        97    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copy.py:182(_deepcopy_atomic)
#         2    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:141(__exit__)
#         7    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         7    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copyreg.py:104(__newobj__)
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:435(validate)
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:863(_addHandlerRef)
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         5    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:228(_acquireLock)
#         1    0.000    0.000    0.000    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/274802400.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/_weakrefset.py:85(add)
#         1    0.000    0.000    0.000    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:26(total_health)
#         2    0.000    0.000    0.000    0.000 /Users/lucastamatescumicrosoft/Code/warhammer-40K-simulator/.venv/lib/python3.11/site-packages/traitlets/traitlets.py:629(get)
#         4    0.000    0.000    0.000    0.000 /Users/lucastamatescumicrosoft/Code/warhammer-40K-simulator/.venv/lib/python3.11/site-packages/IPython/core/compilerop.py:180(extra_flags)
#         1    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         5    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:237(_releaseLock)
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:1646(addHandler)
#         2    0.000    0.000    0.000    0.000 /Users/lucastamatescumicrosoft/Code/warhammer-40K-simulator/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3469(compare)
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:90(RLock)
#         7    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 /Users/lucastamatescumicrosoft/Code/warhammer-40K-simulator/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:1255(user_global_ns)
#        11    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x103718cd0}
#         5    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         7    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/918884673.py:27(<genexpr>)
#         5    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:202(_checkLevel)
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:428(__init__)
#         4    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/typing.py:2256(cast)
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:795(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:1720(getEffectiveLevel)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:983(setFormatter)
#         1    0.000    0.000    0.000    0.000 /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py:1319(disable)

# %%
logger.setLevel(logging.DEBUG)
simulation = Simulation(old_one_eye_squad, genestealer_squad, trials=10)
result = simulation.run()
logger.setLevel(logging.INFO)

result
# Out:
# DEBUG:root:
#
#
# Starting a new trial
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 5. The dice roll was 4 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 5, Remaining damage: 5
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 5
# DEBUG:root:Reduced one health. total health reduced is: 1
# DEBUG:root:Reduced one health. total health reduced is: 2
# DEBUG:root:Unit: Genestealer has died : (  9 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 2, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 5, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 5, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 2, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 3. The dice roll was 2 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 3, Remaining damage: 3
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 3
# DEBUG:root:Reduced one health. total health reduced is: 3
# DEBUG:root:Reduced one health. total health reduced is: 4
# DEBUG:root:Unit: Genestealer has died : (  8 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 6, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 5
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 6
# DEBUG:root:Unit: Genestealer has died : (  7 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 7
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 8
# DEBUG:root:Unit: Genestealer has died : (  6 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 9
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:
#
#
# Starting a new trial
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 5, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 2, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 4. The dice roll was 3 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 4, Remaining damage: 4
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 4
# DEBUG:root:Reduced one health. total health reduced is: 1
# DEBUG:root:Reduced one health. total health reduced is: 2
# DEBUG:root:Unit: Genestealer has died : (  9 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 2. The dice roll was 1 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 2, Remaining damage: 2
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 2
# DEBUG:root:Reduced one health. total health reduced is: 3
# DEBUG:root:Reduced one health. total health reduced is: 4
# DEBUG:root:Unit: Genestealer has died : (  8 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 5
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 6
# DEBUG:root:Unit: Genestealer has died : (  7 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 7
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 8
# DEBUG:root:Unit: Genestealer has died : (  6 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:
#
#
# Starting a new trial
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 2, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 6, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 6, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 1
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 2
# DEBUG:root:Unit: Genestealer has died : (  9 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 5, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 3
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 6, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 4
# DEBUG:root:Unit: Genestealer has died : (  8 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 6, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 5, Modified Armor: 5, Outcome: False
# DEBUG:root:
#
#
# Starting a new trial
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 2, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 7. The dice roll was 6 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 7, Remaining damage: 7
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 7
# DEBUG:root:Reduced one health. total health reduced is: 1
# DEBUG:root:Reduced one health. total health reduced is: 2
# DEBUG:root:Unit: Genestealer has died : (  9 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 4. The dice roll was 3 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 4, Remaining damage: 4
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 4
# DEBUG:root:Reduced one health. total health reduced is: 3
# DEBUG:root:Reduced one health. total health reduced is: 4
# DEBUG:root:Unit: Genestealer has died : (  8 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 4. The dice roll was 3 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 4, Remaining damage: 4
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 4
# DEBUG:root:Reduced one health. total health reduced is: 5
# DEBUG:root:Reduced one health. total health reduced is: 6
# DEBUG:root:Unit: Genestealer has died : (  7 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 4. The dice roll was 3 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 4, Remaining damage: 4
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 4
# DEBUG:root:Reduced one health. total health reduced is: 7
# DEBUG:root:Reduced one health. total health reduced is: 8
# DEBUG:root:Unit: Genestealer has died : (  6 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 7. The dice roll was 6 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 7, Remaining damage: 7
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 7
# DEBUG:root:Reduced one health. total health reduced is: 9
# DEBUG:root:Reduced one health. total health reduced is: 10
# DEBUG:root:Unit: Genestealer has died : (  5 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 6, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 6, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 11
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 12
# DEBUG:root:Unit: Genestealer has died : (  4 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 13
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 14
# DEBUG:root:Unit: Genestealer has died : (  3 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 15
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:
#
#
# Starting a new trial
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 6. The dice roll was 5 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 6, Remaining damage: 6
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 6
# DEBUG:root:Reduced one health. total health reduced is: 1
# DEBUG:root:Reduced one health. total health reduced is: 2
# DEBUG:root:Unit: Genestealer has died : (  9 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 2. The dice roll was 1 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 2, Remaining damage: 2
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 2
# DEBUG:root:Reduced one health. total health reduced is: 3
# DEBUG:root:Reduced one health. total health reduced is: 4
# DEBUG:root:Unit: Genestealer has died : (  8 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 7. The dice roll was 6 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 7, Remaining damage: 7
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 7
# DEBUG:root:Reduced one health. total health reduced is: 5
# DEBUG:root:Reduced one health. total health reduced is: 6
# DEBUG:root:Unit: Genestealer has died : (  7 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 6, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 5, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 7
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 8
# DEBUG:root:Unit: Genestealer has died : (  6 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 9
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:
#
#
# Starting a new trial
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 5. The dice roll was 4 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 5, Remaining damage: 5
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 5
# DEBUG:root:Reduced one health. total health reduced is: 1
# DEBUG:root:Reduced one health. total health reduced is: 2
# DEBUG:root:Unit: Genestealer has died : (  9 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 2, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 4. The dice roll was 3 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 4, Remaining damage: 4
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 4
# DEBUG:root:Reduced one health. total health reduced is: 3
# DEBUG:root:Reduced one health. total health reduced is: 4
# DEBUG:root:Unit: Genestealer has died : (  8 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 6. The dice roll was 5 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 6, Remaining damage: 6
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 6
# DEBUG:root:Reduced one health. total health reduced is: 5
# DEBUG:root:Reduced one health. total health reduced is: 6
# DEBUG:root:Unit: Genestealer has died : (  7 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 6. The dice roll was 5 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 6, Remaining damage: 6
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 6
# DEBUG:root:Reduced one health. total health reduced is: 7
# DEBUG:root:Reduced one health. total health reduced is: 8
# DEBUG:root:Unit: Genestealer has died : (  6 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 9
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 10
# DEBUG:root:Unit: Genestealer has died : (  5 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 11
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 12
# DEBUG:root:Unit: Genestealer has died : (  4 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 13
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 5, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:
#
#
# Starting a new trial
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 4. The dice roll was 3 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 4, Remaining damage: 4
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 4
# DEBUG:root:Reduced one health. total health reduced is: 1
# DEBUG:root:Reduced one health. total health reduced is: 2
# DEBUG:root:Unit: Genestealer has died : (  9 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 3. The dice roll was 2 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 3, Remaining damage: 3
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 3
# DEBUG:root:Reduced one health. total health reduced is: 3
# DEBUG:root:Reduced one health. total health reduced is: 4
# DEBUG:root:Unit: Genestealer has died : (  8 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 6, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 2, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 5, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 5
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 6
# DEBUG:root:Unit: Genestealer has died : (  7 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 7
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 8
# DEBUG:root:Unit: Genestealer has died : (  6 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# ...
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 5
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 6
# DEBUG:root:Unit: Genestealer has died : (  7 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 7
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 8
# DEBUG:root:Unit: Genestealer has died : (  6 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 1, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 9
# DEBUG:root:
#
#
# Starting a new trial
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 3. The dice roll was 2 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 3, Remaining damage: 3
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 3
# DEBUG:root:Reduced one health. total health reduced is: 1
# DEBUG:root:Reduced one health. total health reduced is: 2
# DEBUG:root:Unit: Genestealer has died : (  9 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 4. The dice roll was 3 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 4, Remaining damage: 4
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 4
# DEBUG:root:Reduced one health. total health reduced is: 3
# DEBUG:root:Reduced one health. total health reduced is: 4
# DEBUG:root:Unit: Genestealer has died : (  8 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 5
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 5, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 6
# DEBUG:root:Unit: Genestealer has died : (  7 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 7
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:
#
#
# Starting a new trial
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: get_damage. The amount of damage was: 7. The dice roll was 6 and the added number was 1
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 7, Remaining damage: 7
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 7
# DEBUG:root:Reduced one health. total health reduced is: 1
# DEBUG:root:Reduced one health. total health reduced is: 2
# DEBUG:root:Unit: Genestealer has died : (  9 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_strike, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_strike, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_strike, Dice Roll: 5, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 5, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 6, Modified Armor: 5, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 3, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 3
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 4, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 4
# DEBUG:root:Unit: Genestealer has died : (  8 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 6, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 5
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 4, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 2, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 1, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 6
# DEBUG:root:Unit: Genestealer has died : (  7 remaining out of 10.
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 4, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 3, Opponent Toughness: 4, Outcome: True
# DEBUG:root:The method is: does_it_pass_through_armor, Weapon: old_one_eye_sweep, Dice Roll: 3, Modified Armor: 5, Outcome: True
# DEBUG:root:The method is: feel_no_pain_save, No feel no pain.,Incoming damage: 1, Remaining damage: 1
# DEBUG:root:Unit: Genestealer, Health: 2, Damage: 1
# DEBUG:root:Reduced one health. total health reduced is: 7
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 2, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 1, Ballistic Skill: 3, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 5, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 1, Opponent Toughness: 4, Outcome: False
# DEBUG:root:The method is: does_it_hit. Weapon: old_one_eye_sweep, Dice Roll: 6, Ballistic Skill: 3, Outcome: True
# DEBUG:root:The method is: does_it_wound. Weapon: old_one_eye_sweep, Dice Roll: 2, Opponent Toughness: 4, Outcome: False
# {'damage': [13, 10, 4, 31, 18, 26, 14, 14, 10, 12],
#  'health_reduced': [9, 8, 4, 15, 9, 13, 11, 9, 7, 7],
#  'deaths': [4, 4, 2, 7, 4, 6, 5, 4, 3, 3],
#  'initial_defender_squad_health': 20}

# %%
def calculate_metrics(result):
    result['wasted_damage'] = [d - h for d, h in zip(result['damage'], result['health_reduced'])]
    result['health_reduced_fraction'] = [h / result['initial_defender_squad_health'] for h in result['health_reduced']]

    average_damage = statistics.mean(result['damage'])
    damage_stdev = statistics.stdev(result['damage'])
    average_health_reduced = statistics.mean(result['health_reduced'])
    health_reduced_stdev = statistics.stdev(result['health_reduced'])
    average_wasted_damage=average_damage-average_health_reduced


    def calculate_quartiles_and_iqr(data, key):
        Q1 = round(np.percentile(data[key], 25),2)
        Q2 = round(np.percentile(data[key], 50),2)
        Q3 = round(np.percentile(data[key], 75),2)
        IQR = Q3 - Q1
        return Q1, Q2, Q3, IQR

    Q1_damage, Q2_damage, Q3_damage, IQR_damage = calculate_quartiles_and_iqr(result, 'damage')
    Q1_health_reduced, Q2_health_reduced, Q3_health_reduced, IQR_health_reduced = calculate_quartiles_and_iqr(result, 'health_reduced')
    Q1_wasted_damage, Q2_wasted_damage, Q3_wasted_damage, IQR_wasted_damage = calculate_quartiles_and_iqr(result, 'wasted_damage')
    Q1_deaths, Q2_deaths, Q3_deaths, IQR_deaths = calculate_quartiles_and_iqr(result, 'deaths')
    Q1_health_reduced_fraction, Q2_health_reduced_fraction, Q3_health_reduced_fraction, IQR_health_reduced_fraction = calculate_quartiles_and_iqr(result, 'health_reduced_fraction')

    # print(f"Median damage: {Q2_damage} ({Q1_damage} <> {Q3_damage})")
    # print(f"Median health reduced: {Q2_health_reduced} ({Q1_health_reduced} <> {Q3_health_reduced})")
    # print(f"Median wasted damage: {Q2_wasted_damage} ({Q1_wasted_damage} <> {Q3_wasted_damage})")
    # print(f"Median deaths: {Q2_deaths} ({Q1_deaths} <> {Q3_deaths})")
    # print(f"Median health reduced fraction: {Q2_health_reduced_fraction} ({Q1_health_reduced_fraction} <> {Q3_health_reduced_fraction})")
    # return values as a dict
    return {
        'average_damage': average_damage,
        'damage_stdev': damage_stdev,
        'average_health_reduced': average_health_reduced,
        'health_reduced_stdev': health_reduced_stdev,
        'average_wasted_damage': average_wasted_damage,
        'Q1_damage': Q1_damage,
        'Q2_damage': Q2_damage,
        'Q3_damage': Q3_damage,
        'IQR_damage': IQR_damage,
        'Q1_health_reduced': Q1_health_reduced,
        'Q2_health_reduced': Q2_health_reduced,
        'Q3_health_reduced': Q3_health_reduced,
        'IQR_health_reduced': IQR_health_reduced,
        'Q1_wasted_damage': Q1_wasted_damage,
        'Q2_wasted_damage': Q2_wasted_damage,
        'Q3_wasted_damage': Q3_wasted_damage,
        'IQR_wasted_damage': IQR_wasted_damage,
        'Q1_deaths': Q1_deaths,
        'Q2_deaths': Q2_deaths,
        'Q3_deaths': Q3_deaths,
        'IQR_deaths': IQR_deaths,
        'Q1_health_reduced_fraction': Q1_health_reduced_fraction,
        'Q2_health_reduced_fraction': Q2_health_reduced_fraction,
        'Q3_health_reduced_fraction': Q3_health_reduced_fraction,
        'IQR_health_reduced_fraction': IQR_health_reduced_fraction,
    }

# %% [markdown]
# ## Run comparisons

# %%
import pandas as pd

# Create a list of all squads
squads = [assault_intercessor_ranged_squad, assault_intercessor_melee_squad, genestealer_squad,old_one_eye_squad,redemptor_dreadnought_ranged_squad,redemptor_dreadnought_ranged_supercharged_squad]
# squads = [old_one_eye_squad,redemptor_dreadnought_ranged_squad,redemptor_dreadnought_ranged_supercharged_squad,genestealer_squad]

# Create an empty list to store the results
results = []
colour=[]

trials=1000
logger.info("Total number of trials: " + str(trials*len(squads)*len(squads)))

# Iterate over all pairs of squads
for i in range(len(squads)):
    for j in range(len(squads)):
        # Run a simulation for the current pair of squads
        simulation = Simulation(squads[i], squads[j], trials=trials)
        result = simulation.run()
        metrics=calculate_metrics(result)

        # Store the result in the results list
        results.append({
            'attacker': squads[i].name,
            'defender': squads[j].name,
            'damage': f"{metrics['Q2_damage']} ({metrics['Q1_damage']} <> {metrics['Q3_damage']})",
            'IQR_damage': f"{metrics['IQR_damage']}",
            'health_reduced': f"{metrics['Q2_health_reduced']} ({metrics['Q1_health_reduced']} <> {metrics['Q3_health_reduced']})",
            'IQR_health_reduced': f"{metrics['IQR_health_reduced']}",
            'wasted_damage': f"{metrics['Q2_wasted_damage']} ({metrics['Q1_wasted_damage']} <> {metrics['Q3_wasted_damage']})",
            'deaths': f"{metrics['Q2_deaths']} ({metrics['Q1_deaths']} <> {metrics['Q3_deaths']})",
            'health_reduced_fraction': f"{metrics['Q2_health_reduced_fraction']} ({metrics['Q1_health_reduced_fraction']} <> {metrics['Q3_health_reduced_fraction']})",
        })
        colour.append({
            'attacker': squads[i].name,
            'damage_colour':metrics['Q2_damage'],
            'damage_colour': metrics['Q2_damage'],
            'health_reduced_colour': metrics['Q2_health_reduced'],
            'wasted_damage_colour': metrics['Q2_wasted_damage'],
            'deaths_colour': metrics['Q2_deaths'],
            'health_reduced_fraction_colour': metrics['Q2_health_reduced_fraction'],
            'IQR_damage_colour': metrics['IQR_damage'],
            'IQR_health_reduced_colour': metrics['IQR_health_reduced'],
        })
        

# Convert the results list to a DataFrame
df = pd.DataFrame(results)
df_colour = pd.DataFrame(colour)

# df=df[df['attacker'] == 'Old One Eye Squad']
# df_colour=df_colour[df_colour['attacker'] == 'Old One Eye Squad']

pd.set_option('display.max_colwidth', 30)
# Normalize each column to range [0, 1], grouped by "attacker"
normalized_df_colour = df_colour.groupby('attacker').transform(lambda x: (x - x.min()) / (x.max() - x.min()))

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

def color_map(val, reverse=False):
    cmap = plt.get_cmap('RdYlGn')  # Get the colormap
    if reverse:
        cmap = cmap.reversed()  # Reverse the colormap
    norm = mcolors.Normalize(vmin=0, vmax=1)  # Normalize the values to range [0, 1]
    
    rgba = cmap(norm(val))  # Get the rgba value from the colormap
    return f'background-color: {mcolors.rgb2hex(rgba)}'  # Convert rgba to hex and return as CSS

# Create a Styler object from df
styled_df = df.style

# Apply the color map to only 'health_reduced_fraction' column in df using the values in color_df
styled_df = styled_df.apply(lambda s: normalized_df_colour['damage_colour'].apply(lambda x: color_map(x, reverse=False)), subset=['damage'])
styled_df = styled_df.apply(lambda s: normalized_df_colour['health_reduced_colour'].apply(lambda x: color_map(x, reverse=False)), subset=['health_reduced'])
styled_df = styled_df.apply(lambda s: normalized_df_colour['wasted_damage_colour'].apply(lambda x: color_map(x, reverse=True)), subset=['wasted_damage'])
styled_df = styled_df.apply(lambda s: normalized_df_colour['health_reduced_fraction_colour'].apply(lambda x: color_map(x, reverse=False)), subset=['health_reduced_fraction'])
styled_df = styled_df.apply(lambda s: normalized_df_colour['IQR_damage_colour'].apply(lambda x: color_map(x, reverse=True)), subset=['IQR_damage'])
styled_df = styled_df.apply(lambda s: normalized_df_colour['IQR_health_reduced_colour'].apply(lambda x: color_map(x, reverse=True)), subset=['IQR_health_reduced'])

## show full width
# styled_df = styled_df.set_properties(**{'white-space': 'nowrap', 'overflow': 'hidden'})

# hide when text is too long
styled_df = styled_df.set_properties(**{'max-width': '150px', 'white-space': 'nowrap', 'overflow': 'hidden'})

# #add scrollbar when text is too long
# styled_df = styled_df.set_properties(**{'max-width': '150px', 'white-space': 'nowrap', 'overflow': 'auto'})

styled_df
# Out:
# /var/folders/04/byk1dtp95sn0gjlx1gsgdqkw0000gn/T/ipykernel_44186/63010485.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# INFO:root:Total number of trials: 36000
# <style type="text/css">
# #T_238de_row0_col0, #T_238de_row0_col1, #T_238de_row0_col7, #T_238de_row1_col0, #T_238de_row1_col1, #T_238de_row1_col7, #T_238de_row2_col0, #T_238de_row2_col1, #T_238de_row2_col7, #T_238de_row3_col0, #T_238de_row3_col1, #T_238de_row3_col7, #T_238de_row4_col0, #T_238de_row4_col1, #T_238de_row4_col7, #T_238de_row5_col0, #T_238de_row5_col1, #T_238de_row5_col7, #T_238de_row6_col0, #T_238de_row6_col1, #T_238de_row6_col7, #T_238de_row7_col0, #T_238de_row7_col1, #T_238de_row7_col7, #T_238de_row8_col0, #T_238de_row8_col1, #T_238de_row8_col7, #T_238de_row9_col0, #T_238de_row9_col1, #T_238de_row9_col7, #T_238de_row10_col0, #T_238de_row10_col1, #T_238de_row10_col7, #T_238de_row11_col0, #T_238de_row11_col1, #T_238de_row11_col7, #T_238de_row12_col0, #T_238de_row12_col1, #T_238de_row12_col7, #T_238de_row13_col0, #T_238de_row13_col1, #T_238de_row13_col7, #T_238de_row14_col0, #T_238de_row14_col1, #T_238de_row14_col7, #T_238de_row15_col0, #T_238de_row15_col1, #T_238de_row15_col7, #T_238de_row16_col0, #T_238de_row16_col1, #T_238de_row16_col7, #T_238de_row17_col0, #T_238de_row17_col1, #T_238de_row17_col7, #T_238de_row18_col0, #T_238de_row18_col1, #T_238de_row18_col7, #T_238de_row19_col0, #T_238de_row19_col1, #T_238de_row19_col7, #T_238de_row20_col0, #T_238de_row20_col1, #T_238de_row20_col7, #T_238de_row21_col0, #T_238de_row21_col1, #T_238de_row21_col7, #T_238de_row22_col0, #T_238de_row22_col1, #T_238de_row22_col7, #T_238de_row23_col0, #T_238de_row23_col1, #T_238de_row23_col7, #T_238de_row24_col0, #T_238de_row24_col1, #T_238de_row24_col7, #T_238de_row25_col0, #T_238de_row25_col1, #T_238de_row25_col7, #T_238de_row26_col0, #T_238de_row26_col1, #T_238de_row26_col7, #T_238de_row27_col0, #T_238de_row27_col1, #T_238de_row27_col7, #T_238de_row28_col0, #T_238de_row28_col1, #T_238de_row28_col7, #T_238de_row29_col0, #T_238de_row29_col1, #T_238de_row29_col7, #T_238de_row30_col0, #T_238de_row30_col1, #T_238de_row30_col7, #T_238de_row31_col0, #T_238de_row31_col1, #T_238de_row31_col7, #T_238de_row32_col0, #T_238de_row32_col1, #T_238de_row32_col7, #T_238de_row33_col0, #T_238de_row33_col1, #T_238de_row33_col7, #T_238de_row34_col0, #T_238de_row34_col1, #T_238de_row34_col7, #T_238de_row35_col0, #T_238de_row35_col1, #T_238de_row35_col7 {
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row0_col2, #T_238de_row0_col4, #T_238de_row0_col8, #T_238de_row1_col2, #T_238de_row1_col4, #T_238de_row1_col8, #T_238de_row2_col2, #T_238de_row2_col4, #T_238de_row3_col3, #T_238de_row3_col5, #T_238de_row6_col3, #T_238de_row6_col5, #T_238de_row6_col8, #T_238de_row7_col3, #T_238de_row7_col5, #T_238de_row7_col8, #T_238de_row8_col2, #T_238de_row8_col4, #T_238de_row9_col3, #T_238de_row9_col5, #T_238de_row10_col3, #T_238de_row10_col5, #T_238de_row11_col3, #T_238de_row11_col5, #T_238de_row12_col3, #T_238de_row12_col5, #T_238de_row12_col8, #T_238de_row13_col3, #T_238de_row13_col5, #T_238de_row13_col8, #T_238de_row14_col2, #T_238de_row14_col4, #T_238de_row18_col2, #T_238de_row18_col4, #T_238de_row18_col5, #T_238de_row18_col8, #T_238de_row19_col4, #T_238de_row19_col5, #T_238de_row19_col8, #T_238de_row20_col4, #T_238de_row20_col5, #T_238de_row21_col3, #T_238de_row21_col6, #T_238de_row22_col4, #T_238de_row22_col6, #T_238de_row23_col4, #T_238de_row23_col6, #T_238de_row24_col2, #T_238de_row24_col4, #T_238de_row24_col8, #T_238de_row25_col2, #T_238de_row25_col4, #T_238de_row25_col8, #T_238de_row26_col2, #T_238de_row26_col4, #T_238de_row27_col3, #T_238de_row27_col5, #T_238de_row30_col2, #T_238de_row31_col2, #T_238de_row31_col4, #T_238de_row31_col8, #T_238de_row32_col4, #T_238de_row33_col3, #T_238de_row33_col5, #T_238de_row33_col6, #T_238de_row34_col6, #T_238de_row35_col6 {
#   background-color: #006837;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row0_col3, #T_238de_row0_col5, #T_238de_row1_col3, #T_238de_row1_col5, #T_238de_row4_col3, #T_238de_row4_col5, #T_238de_row5_col3, #T_238de_row5_col5, #T_238de_row20_col3, #T_238de_row26_col3, #T_238de_row26_col5, #T_238de_row28_col3, #T_238de_row28_col5, #T_238de_row29_col3, #T_238de_row29_col5, #T_238de_row31_col5, #T_238de_row32_col5, #T_238de_row34_col5, #T_238de_row35_col5 {
#   background-color: #fffebe;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row0_col6, #T_238de_row1_col6, #T_238de_row2_col6, #T_238de_row3_col6, #T_238de_row4_col6, #T_238de_row5_col6, #T_238de_row6_col6, #T_238de_row7_col6, #T_238de_row8_col6, #T_238de_row9_col6, #T_238de_row10_col6, #T_238de_row11_col6, #T_238de_row12_col6, #T_238de_row13_col6, #T_238de_row14_col6, #T_238de_row15_col6, #T_238de_row16_col6, #T_238de_row17_col6, #T_238de_row24_col6, #T_238de_row25_col6, #T_238de_row26_col6, #T_238de_row27_col6, #T_238de_row28_col6, #T_238de_row29_col6 {
#   background-color: #000000;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row2_col3, #T_238de_row2_col5, #T_238de_row3_col2, #T_238de_row3_col4, #T_238de_row3_col8, #T_238de_row4_col2, #T_238de_row4_col4, #T_238de_row4_col8, #T_238de_row5_col2, #T_238de_row5_col4, #T_238de_row5_col8, #T_238de_row8_col3, #T_238de_row8_col5, #T_238de_row9_col2, #T_238de_row9_col4, #T_238de_row9_col8, #T_238de_row14_col3, #T_238de_row14_col5, #T_238de_row15_col2, #T_238de_row15_col4, #T_238de_row16_col8, #T_238de_row17_col8, #T_238de_row18_col3, #T_238de_row18_col6, #T_238de_row19_col3, #T_238de_row19_col6, #T_238de_row20_col8, #T_238de_row21_col2, #T_238de_row21_col4, #T_238de_row22_col5, #T_238de_row23_col5, #T_238de_row24_col3, #T_238de_row24_col5, #T_238de_row25_col3, #T_238de_row25_col5, #T_238de_row27_col2, #T_238de_row27_col4, #T_238de_row27_col8, #T_238de_row30_col3, #T_238de_row30_col5, #T_238de_row30_col6, #T_238de_row31_col3, #T_238de_row31_col6, #T_238de_row32_col6, #T_238de_row33_col2, #T_238de_row33_col4, #T_238de_row33_col8 {
#   background-color: #a50026;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row2_col8 {
#   background-color: #feffbe;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row6_col2, #T_238de_row6_col4, #T_238de_row7_col2, #T_238de_row7_col4 {
#   background-color: #84ca66;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row8_col8 {
#   background-color: #fffab6;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row10_col2, #T_238de_row10_col4, #T_238de_row11_col2, #T_238de_row11_col4 {
#   background-color: #f98e52;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row10_col8, #T_238de_row11_col8 {
#   background-color: #f47044;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row12_col2, #T_238de_row12_col4, #T_238de_row13_col2, #T_238de_row13_col4, #T_238de_row32_col2 {
#   background-color: #39a758;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row14_col8 {
#   background-color: #f67c4a;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row15_col3, #T_238de_row15_col5, #T_238de_row16_col3, #T_238de_row16_col5, #T_238de_row17_col3, #T_238de_row17_col5, #T_238de_row32_col3 {
#   background-color: #fdbf6f;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row15_col8 {
#   background-color: #b50f26;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row16_col2, #T_238de_row16_col4, #T_238de_row17_col2, #T_238de_row17_col4, #T_238de_row34_col2, #T_238de_row35_col2 {
#   background-color: #e34933;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row19_col2 {
#   background-color: #0d8044;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row20_col2 {
#   background-color: #45ad5b;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row20_col6 {
#   background-color: #ea5739;
#   max-width: 150px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_238de_row21_col5 {
#   background-color: #87cb67;
#   max-width: 150px;
#   white-space:
